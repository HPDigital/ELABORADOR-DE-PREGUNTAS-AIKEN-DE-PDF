# %%
# esta finciona bien para un solo documento PDF
import fitz  # PyMuPDF
from openai import OpenAI

def create_openai_client(api_key):
    return OpenAI(api_key=api_key)

def create_assistant(client, name, instructions, model="gpt-4o"):
    return client.beta.assistants.create(
        name=name,
        instructions=instructions,
        model=model,
        tools=[{"type": "file_search"}],
    )

def create_vector_store(client, name):
    return client.beta.vector_stores.create(name=name)

def extract_text_from_pdf(file_paths):
    extracted_texts = []
    for path in file_paths:
        with fitz.open(path) as pdf_file:
            text = "".join(page.get_text() for page in pdf_file)
        extracted_texts.append(text)
    return extracted_texts

def save_texts_to_files(extracted_texts):
    temp_txt_paths = []
    for i, text in enumerate(extracted_texts):
        temp_txt_path = f"temp_extracted_text_{i}.txt"
        with open(temp_txt_path, "w", encoding="utf-8") as temp_file:
            temp_file.write(text)
        temp_txt_paths.append(temp_txt_path)
    return temp_txt_paths

def upload_files_to_vector_store(client, vector_store_id, temp_txt_paths):
    file_streams = [open(path, "rb") for path in temp_txt_paths]
    file_batch = client.beta.vector_stores.file_batches.upload_and_poll(
        vector_store_id=vector_store_id, files=file_streams
    )
    return file_batch

def create_message_file(client, file_path):
    return client.files.create(
        file=open(file_path, "rb"), purpose="assistants"
    )

def create_thread(client, assistant_id, message_file_id, content):
    thread = client.beta.threads.create(
        messages=[
            {
                "role": "user",
                "content": content,
                "attachments": [
                    {"file_id": message_file_id, "tools": [{"type": "file_search"}]}
                ],
            }
        ]
    )
    return thread

def run_thread(client, thread_id, assistant_id):
    run = client.beta.threads.runs.create_and_poll(
        thread_id=thread_id, assistant_id=assistant_id
    )
    messages = list(client.beta.threads.messages.list(thread_id=thread_id, run_id=run.id))
    return messages

def main():
    api_key = "YOUR_API_KEY_HERE"
    client = create_openai_client(api_key)

    assistant = create_assistant(
        client,
        name="Elaborador",
        instructions="""Eres un experto en elaboración de preguntas didácticas para evaluaciones. 
        No proporcionas las fuentes ni haces citaciones. 
        No das un texto de introducción, ni de despedida. 
        Únicamente respondes con las preguntas solicitadas en el formato AIKEN, sin más ni menos."""
    )

    vector_store = create_vector_store(client, name="Texto_adjunto")

    file_paths = ["C:\\Users\\HP\\Desktop\\CATO-CURSOS-2-2024\\CURSO SIS-SOP-CATO-1-2024\\Semana 3\\SEMANA 3 RECURSOS\\El CRM como estrategia de negocio desarrollo de un modelo de éxito y análisis empírico en el sector hotelero español.pdf"]
    extracted_texts = extract_text_from_pdf(file_paths)
    temp_txt_paths = save_texts_to_files(extracted_texts)

    file_batch = upload_files_to_vector_store(client, vector_store.id, temp_txt_paths)
    print("File batch status:", file_batch.status)
    print("File batch counts:", file_batch.file_counts)

    assistant = client.beta.assistants.update(
        assistant_id=assistant.id,
        tool_resources={"file_search": {"vector_store_ids": [vector_store.id]}},
    )

    message_file = create_message_file(client, temp_txt_paths[0])

    content = """Elabora VEINTE preguntas en formato AIKEN basadas en el texto proporcionado. 
    Las preguntas deben centrarse en el tema principal del texto. 
    No debes proporcionar citaciones ni incluir introducción o despedida. 
    Solo responde con las preguntas en el formato AIKEN.
    
    Ejemplo de preguntas:
    
    Según el texto de título: Business Storytelling Masterclass with Matteo Cassese, ¿qué es esencial para captar la atención del público en storytelling?
    A) Utilizar terminología complicada
    B) Hablar en un tono monótono
    C) Empezar con una anécdota interesante
    D) Presentar gráficos complejos
    ANSWER: C
    """

    thread = create_thread(client, assistant.id, message_file.id, content)
    messages = run_thread(client, thread.id, assistant.id)

    if messages:
        message_content = messages[0].content[0].text
        print("Generated Questions:")
        print(message_content.value)
    else:
        print("No messages returned from the thread.")

if __name__ == "__main__":
    main()
# Out:
# File batch status: completed
# File batch counts: FileCounts(cancelled=0, completed=1, failed=0, in_progress=0, total=1)
# Generated Questions:
# ¿Cuál es una de las razones principales por las que las empresas implementan CRM?
# A) Reducir el número de empleados
# B) Incrementar la cuota de mercado
# C) Aumentar el gasto en publicidad
# D) Disminuir el número de productos
# ANSWER: B
#
# ¿Qué factor es crucial para el éxito de una estrategia CRM según el texto?
# A) Diseño gráfico
# B) Publicidad masiva
# C) Cultura organizativa
# D) Automación de tareas
# ANSWER: C
#
# ¿Cuál es el papel de la tecnología en la gestión del conocimiento según el texto?
# A) Es irrelevante para la gestión del conocimiento
# B) Facilita la gestión del conocimiento
# C) Solo tiene un impacto negativo
# D) Reemplaza la necesidad de personal capacitado
# ANSWER: B
#
# ¿Cuál es una de las variables que inciden en una exitosa gestión del conocimiento de clientes?
# A) Reducción de precios
# B) Proceso de información
# C) Publicidad en redes sociales
# D) Número de empleados
# ANSWER: B
#
# ¿Cómo se considera la gestión del conocimiento según la propuesta conceptual de Gorelick y Tantawy-Monsou?
# A) Un sistema aislado sin integración tecnológica
# B) Un sistema que integra personas, procesos y tecnología
# C) Un proceso tecnológico exclusivamente
# D) Una estrategia de marketing
# ANSWER: B
#
# ¿Qué impacto tiene la adquisición de conocimiento en los resultados de la implementación del CRM?
# A) No tiene ningún impacto
# B) Un impacto negativo
# C) Un impacto directo e indirecto
# D) Solo un impacto indirecto
# ANSWER: C
#
# ¿Qué mide la empresa con frecuencia para mejorar su orientación al cliente?
# A) El número de empleados
# B) La satisfacción de sus clientes
# C) El tamaño de sus instalaciones
# D) La cantidad de ventas
# ANSWER: B
#
# ¿Qué tipo de productos y servicios ofrece la empresa para sus principales clientes?
# A) Genéricos y poco específicos
# B) Personalizados y específicos
# C) Antiguos y ya obsoletos
# D) Baratos y de baja calidad
# ANSWER: B
#
# ¿Cuál es uno de los factores tecnológicos indispensables para la gestión de CRM?
# A) Publicidad en radio
# B) Hardware adecuado
# C) Número de sucursales
# D) Equipo de ventas amplio
# ANSWER: B
#
# ¿Qué es fundamental para proporcionar apoyo técnico en la utilización de tecnología CRM?
# A) Canales de televisión
# B) Personal técnico adecuado
# C) Reducción de costos
# D) Aumento de precios
# ANSWER: B
#
# ¿Qué requiere la introducción de nuevos sistemas tecnológicos para el CRM, según el texto?
# A) Reducción en la formación del personal
# B) Cambios significativos en la organización
# C) Eliminación de departamentos
# D) Outsourcing de todos los servicios
# ANSWER: B
#
# ¿Qué factor puede ser un impedimento para la implementación del CRM en hoteles según el estudio citado?
# A) Tamaño de los hoteles
# B) Desconocimiento de soluciones de CRM
# C) Volumen de negocio generado
# D) Número de camas disponibles
# ANSWER: B
#
# ¿Cuál es una de las razones por las que los hoteles no están implementando CRM?
# A) Falta de interés en tecnología
# B) Desconocimiento de soluciones y ventajas del CRM
# C) Preferencia por métodos tradicionales
# D) Disponibilidad de personal excesivo
# ANSWER: B
#
# ¿Cuál es el porcentaje de hoteles que implementaron una estrategia CRM según el texto?
# A) 72.5%
# B) 49.2%
# C) 30%
# D) 15%
# ANSWER: B
#
# ¿Qué tipo de hoteles fueron seleccionados para el estudio empírico mencionado en el texto?
# A) Hoteles de una y dos estrellas
# B) Hoteles de tres a cinco estrellas
# C) Hostales
# D) Apartamentos turísticos
# ANSWER: B
#
# ¿Qué impacto tiene la experiencia en CRM de las empresas en los resultados del mismo?
# A) No tiene ningún impacto
# B) Impacto directo
# C) Impacto inverso
# D) Impacto negativo
# ANSWER: B
#
# ¿Qué porcentaje de hoteles implementaron CRM por más de dos años según el texto?
# A) 30.2%
# B) 60.5%
# C) 50.3%
# D) 43.8%
# ANSWER: C
#
# ¿En qué se basa la ventaja competitiva de la empresa orientada al cliente?
# A) Reducción de precios
# B) Comprensión de necesidades del cliente
# C) Incremento de publicidad
# D) Ampliación de la gama de productos
# ANSWER: B
#
# ¿Qué enfoque constituye el corazón de la orientación al mercado en una empresa?
# A) Enfoque en productos antiguos
# B) Enfoque en clientes
# C) Enfoque en reducción de precios
# D) Enfoque en competidores
# ANSWER: B
#
# Según el texto, ¿qué se estima que sucederá con los niveles de implementación de CRM en el sector hotelero en el futuro?
# A) Se reducirán significativamente
# B) No mostrarán cambios
# C) Se incrementarán notablemente
# D) Desaparecerán gradualmente
# ANSWER: C

# %%
#Esta funciona bien para trabajar con todos los PDFs d euna carpeta

import os
import fitz  # PyMuPDF
from openai import OpenAI

def create_openai_client(api_key):
    return OpenAI(api_key=api_key)

def create_assistant(client, name, instructions, model="gpt-4o"):
    return client.beta.assistants.create(
        name=name,
        instructions=instructions,
        model=model,
        tools=[{"type": "file_search"}],
    )

def create_vector_store(client, name):
    return client.beta.vector_stores.create(name=name)

def extract_text_from_pdf(file_paths):
    extracted_texts = []
    for path in file_paths:
        with fitz.open(path) as pdf_file:
            text = "".join(page.get_text() for page in pdf_file)
        extracted_texts.append(text)
    return extracted_texts

def save_texts_to_files(extracted_texts, output_dir, original_file_names):
    temp_txt_paths = []
    for i, text in enumerate(extracted_texts):
        # Use the original PDF file name for the TXT file
        original_file_name = os.path.splitext(os.path.basename(original_file_names[i]))[0]
        temp_txt_path = os.path.join(output_dir, f"{original_file_name}.txt")
        with open(temp_txt_path, "w", encoding="utf-8") as temp_file:
            temp_file.write(text)
        temp_txt_paths.append(temp_txt_path)
    return temp_txt_paths

def upload_files_to_vector_store(client, vector_store_id, temp_txt_paths):
    file_streams = [open(path, "rb") for path in temp_txt_paths]
    file_batch = client.beta.vector_stores.file_batches.upload_and_poll(
        vector_store_id=vector_store_id, files=file_streams
    )
    return file_batch

def create_message_file(client, file_path):
    return client.files.create(
        file=open(file_path, "rb"), purpose="assistants"
    )

def create_thread(client, assistant_id, message_file_id, content):
    thread = client.beta.threads.create(
        messages=[
            {
                "role": "user",
                "content": content,
                "attachments": [
                    {"file_id": message_file_id, "tools": [{"type": "file_search"}]}
                ],
            }
        ]
    )
    return thread

def run_thread(client, thread_id, assistant_id):
    run = client.beta.threads.runs.create_and_poll(
        thread_id=thread_id, assistant_id=assistant_id
    )
    messages = list(client.beta.threads.messages.list(thread_id=thread_id, run_id=run.id))
    return messages

def main():
    api_key = "YOUR_API_KEY_HERE"
    client = create_openai_client(api_key)

    assistant = create_assistant(
        client,
        name="Elaborador",
        instructions="""Eres un experto en elaboración de preguntas didácticas para evaluaciones. 
        No proporcionas las fuentes ni haces citaciones. 
        No das un texto de introducción, ni de despedida. 
        Únicamente respondes con las preguntas solicitadas en el formato AIKEN, sin más ni menos."""
    )

    vector_store = create_vector_store(client, name="Texto_adjunto")

    # Ruta del directorio donde están los archivos PDF
    input_dir = r"C:\Users\HP\Desktop\CATO-CURSOS-2-2024\GER-TI CATO1-2024\Cursos\SEMANA 2\BUSINESS MODEL CANVAS\texto_videos\texto_pdf"

    # Lista de todos los archivos PDF en el directorio
    file_paths = [os.path.join(input_dir, f) for f in os.listdir(input_dir) if f.endswith('.pdf')]

    extracted_texts = extract_text_from_pdf(file_paths)
    temp_txt_paths = save_texts_to_files(extracted_texts, input_dir, file_paths)

    file_batch = upload_files_to_vector_store(client, vector_store.id, temp_txt_paths)
    print("File batch status:", file_batch.status)
    print("File batch counts:", file_batch.file_counts)

    assistant = client.beta.assistants.update(
        assistant_id=assistant.id,
        tool_resources={"file_search": {"vector_store_ids": [vector_store.id]}},
    )

    for temp_txt_path in temp_txt_paths:
        message_file = create_message_file(client, temp_txt_path)

        content = """Elabora VEINTE preguntas en formato AIKEN basadas en el texto proporcionado. 
        Las preguntas deben centrarse en el tema principal del texto. 
        No debes proporcionar citaciones ni incluir introducción o despedida. 
        Solo responde con las preguntas en el formato AIKEN.
        
        Ejemplo de preguntas:
        
        Según el texto de título: Business Storytelling Masterclass with Matteo Cassese, ¿qué es esencial para captar la atención del público en storytelling?
        A) Utilizar terminología complicada
        B) Hablar en un tono monótono
        C) Empezar con una anécdota interesante
        D) Presentar gráficos complejos
        ANSWER: C
        """

        thread = create_thread(client, assistant.id, message_file.id, content)
        messages = run_thread(client, thread.id, assistant.id)

        if messages:
            message_content = messages[0].content[0].text
            # Guardar las preguntas en un archivo TXT con el mismo nombre del archivo PDF
            output_txt_path = os.path.join(input_dir, os.path.basename(temp_txt_path))
            with open(output_txt_path, "w", encoding="utf-8") as output_file:
                output_file.write(message_content.value)
            print(f"Preguntas guardadas en: {output_txt_path}")
        else:
            print("No messages returned from the thread.")

if __name__ == "__main__":
    main()
# Out:
# File batch status: completed
# File batch counts: FileCounts(cancelled=0, completed=9, failed=0, in_progress=0, total=9)
# No messages returned from the thread.
# No messages returned from the thread.
# No messages returned from the thread.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 138
#     135             print("No messages returned from the thread.")
#     137 if __name__ == "__main__":
# --> 138     main()
#
# Cell In[2], line 125, in main()
#     109 content = """Elabora VEINTE preguntas en formato AIKEN basadas en el texto proporcionado.
#     110 Las preguntas deben centrarse en el tema principal del texto.
#     111 No debes proporcionar citaciones ni incluir introducción o despedida.
#    (...)
#     121 ANSWER: C
#     122 """
#     124 thread = create_thread(client, assistant.id, message_file.id, content)
# --> 125 messages = run_thread(client, thread.id, assistant.id)
#     127 if messages:
#     128     message_content = messages[0].content[0].text
#
# Cell In[2], line 67, in run_thread(client, thread_id, assistant_id)
#      66 def run_thread(client, thread_id, assistant_id):
# ---> 67     run = client.beta.threads.runs.create_and_poll(
#      68         thread_id=thread_id, assistant_id=assistant_id
#      69     )
#      70     messages = list(client.beta.threads.messages.list(thread_id=thread_id, run_id=run.id))
#      71     return messages
#
# File ~\anaconda3\Lib\site-packages\openai\resources\beta\threads\runs\runs.py:767, in Runs.create_and_poll(self, assistant_id, additional_instructions, additional_messages, instructions, max_completion_tokens, max_prompt_tokens, metadata, model, parallel_tool_calls, response_format, temperature, tool_choice, tools, top_p, truncation_strategy, poll_interval_ms, thread_id, extra_headers, extra_query, extra_body, timeout)
#     738 """
#     739 A helper to create a run an poll for a terminal state. More information on Run
#     740 lifecycles can be found here:
#     741 https://platform.openai.com/docs/assistants/how-it-works/runs-and-run-steps
#     742 """
#     743 run = self.create(
#     744     thread_id=thread_id,
#     745     assistant_id=assistant_id,
#    (...)
#     765     timeout=timeout,
#     766 )
# --> 767 return self.poll(
#     768     run.id,
#     769     thread_id=thread_id,
#     770     extra_headers=extra_headers,
#     771     extra_query=extra_query,
#     772     extra_body=extra_body,
#     773     poll_interval_ms=poll_interval_ms,
#     774     timeout=timeout,
#     775 )
#
# File ~\anaconda3\Lib\site-packages\openai\resources\beta\threads\runs\runs.py:933, in Runs.poll(self, run_id, thread_id, extra_headers, extra_query, extra_body, timeout, poll_interval_ms)
#     931 terminal_states = {"requires_action", "cancelled", "completed", "failed", "expired", "incomplete"}
#     932 while True:
# --> 933     response = self.with_raw_response.retrieve(
#     934         thread_id=thread_id,
#     935         run_id=run_id,
#     936         extra_headers=extra_headers,
#     937         extra_body=extra_body,
#     938         extra_query=extra_query,
#     939         timeout=timeout,
#     940     )
#     942     run = response.parse()
#     943     # Return if we reached a terminal state
#
# File ~\anaconda3\Lib\site-packages\openai\_legacy_response.py:350, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     346 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     348 kwargs["extra_headers"] = extra_headers
# --> 350 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\anaconda3\Lib\site-packages\openai\resources\beta\threads\runs\runs.py:555, in Runs.retrieve(self, run_id, thread_id, extra_headers, extra_query, extra_body, timeout)
#     553     raise ValueError(f"Expected a non-empty value for `run_id` but received {run_id!r}")
#     554 extra_headers = {"OpenAI-Beta": "assistants=v2", **(extra_headers or {})}
# --> 555 return self._get(
#     556     f"/threads/{thread_id}/runs/{run_id}",
#     557     options=make_request_options(
#     558         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     559     ),
#     560     cast_to=Run,
#     561 )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:1205, in SyncAPIClient.get(self, path, cast_to, options, stream, stream_cls)
#    1202 opts = FinalRequestOptions.construct(method="get", url=path, **options)
#    1203 # cast is required because mypy complains about returning Any even though
#    1204 # it understands the type variables
# -> 1205 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:936, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     927 def request(
#     928     self,
#     929     cast_to: Type[ResponseT],
#    (...)
#     934     stream_cls: type[_StreamT] | None = None,
#     935 ) -> ResponseT | _StreamT:
# --> 936     return self._request(
#     937         cast_to=cast_to,
#     938         options=options,
#     939         stream=stream,
#     940         stream_cls=stream_cls,
#     941         remaining_retries=remaining_retries,
#     942     )
#
# File ~\anaconda3\Lib\site-packages\openai\_base_client.py:972, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     969 log.debug("Sending HTTP Request: %s %s", request.method, request.url)
#     971 try:
# --> 972     response = self._client.send(
#     973         request,
#     974         stream=stream or self._should_stream_response_body(request=request),
#     975         **kwargs,
#     976     )
#     977 except httpx.TimeoutException as err:
#     978     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     906 follow_redirects = (
#     907     self.follow_redirects
#     908     if isinstance(follow_redirects, UseClientDefault)
#     909     else follow_redirects
#     910 )
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\anaconda3\Lib\site-packages\httpx\_client.py:1015, in Client._send_single_request(self, request)
#    1010     raise RuntimeError(
#    1011         "Attempted to send an async request with a sync Client instance."
#    1012     )
#    1014 with request_context(request=request):
# -> 1015     response = transport.handle_request(request)
#    1017 assert isinstance(response.stream, SyncByteStream)
#    1019 response.request = request
#
# File ~\anaconda3\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     220 req = httpcore.Request(
#     221     method=request.method,
#     222     url=httpcore.URL(
#    (...)
#     230     extensions=request.extensions,
#     231 )
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#     237 return Response(
#     238     status_code=resp.status,
#     239     headers=resp.headers,
#     240     stream=ResponseStream(resp.stream),
#     241     extensions=resp.extensions,
#     242 )
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     266     with ShieldCancellation():
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return self._connection.handle_request(request)
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:133, in HTTP11Connection.handle_request(self, request)
#     131     with Trace("response_closed", logger, request) as trace:
#     132         self._response_closed()
# --> 133 raise exc
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:111, in HTTP11Connection.handle_request(self, request)
#     101     pass
#     103 with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:176, in HTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~\anaconda3\Lib\site-packages\httpcore\_sync\http11.py:212, in HTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\anaconda3\Lib\site-packages\httpcore\_backends\sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# File ~\anaconda3\Lib\ssl.py:1295, in SSLSocket.recv(self, buflen, flags)
#    1291     if flags != 0:
#    1292         raise ValueError(
#    1293             "non-zero flags not allowed in calls to recv() on %s" %
#    1294             self.__class__)
# -> 1295     return self.read(buflen)
#    1296 else:
#    1297     return super().recv(buflen, flags)
#
# File ~\anaconda3\Lib\ssl.py:1168, in SSLSocket.read(self, len, buffer)
#    1166         return self._sslobj.read(len, buffer)
#    1167     else:
# -> 1168         return self._sslobj.read(len)
#    1169 except SSLError as x:
#    1170     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:
